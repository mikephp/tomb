# %%
import util
import pandas as pd
import datetime as dt

# %%
dt_start = dt.datetime(2014, 1,1)
dt_end = dt.datetime.today()

# %%
d_data = util.stock_data(dt_start, dt_end, ['JD', 'TEAM', 'AAPL'])

# %%
df_price= (util.close_price(d_data))

# %%
(_,_,_,df_bb_ratio) = util.bollinger_band(df_price, lookback=20, ratio = 2)

# %%
reload(util)
util.reverse_bollinger_band(df_price[-20:], ratio = 2)
# Out:
# (JD      24.031858
# AAPL    91.174705
# TEAM    22.198307
# dtype: float64,
#  JD       34.374143
# AAPL    111.890293
# TEAM     31.857693
# dtype: float64)

# %%
df_price[-20:]
# Out:
#                    JD        AAPL       TEAM
# 2015-12-23  32.540001  108.610001  28.490000
# 2015-12-24  32.580002  108.029999  28.209999
# 2015-12-28  31.889999  106.820000  28.900000
# 2015-12-29  32.650002  108.739998  31.100000
# 2015-12-30  32.080002  107.320000  30.209999
# 2015-12-31  32.264999  105.260002  30.080000
# 2016-01-04  29.530001  105.349998  27.410000
# 2016-01-05  30.000000  102.709999  26.770000
# 2016-01-06  29.760000  100.699997  27.049999
# 2016-01-07  27.950001   96.449997  26.969999
# 2016-01-08  27.620001   96.959999  27.170000
# 2016-01-11  27.030001   98.529999  27.120001
# 2016-01-12  28.205000   99.959999  26.820000
# 2016-01-13  27.100000   97.389999  26.730000
# 2016-01-14  28.120001   99.519997  26.840000
# 2016-01-15  26.990000   97.129997  25.190001
# 2016-01-19  27.410000   96.660004  24.020000
# 2016-01-20  26.379999   96.790001  22.629999
# 2016-01-21  26.690001   96.300003  24.240000
# 2016-01-22  27.270000  101.419998  24.610001
#
# [20 rows x 3 columns]
